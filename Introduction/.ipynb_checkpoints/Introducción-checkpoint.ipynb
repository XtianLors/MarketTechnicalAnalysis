# %%
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import seaborn as sns
import math as m

# %%
dti = pd.to_datetime(
    ["1/1/2018", np.datetime64("2018-01-01"), datetime.datetime(2018, 1, 1)]
)

# %%
print(dti)
print(type(dti))
print(str(dti))
print(len(dti))
print('Metods in dti: ', len(dir(dti)))
print(dir(dti)[0:5])
try:
    print(dti['2018-01-01'])#No funciona puesto que el índice no está definido
except IndexError:
    print("Index Error")
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)
# 3
# Metods in dti:  385
# ['T', '__abs__', '__abstractmethods__', '__add__', '__and__']
# Index Error

# %%
for i in dti:
    print(i)
# Out:
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00

# %%
for i in dti:
    print(type(i))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
print("Are these values the same? \n", dti[0] == dti[1])
print("Are these values the same? \n", dti[0] == dti[2])
print("Are these values the same? \n", dti[1] == dti[2])
print("As you can see, pd.to_datetime converts '1/1/2018', np.datetime64('2018-01-01'), datetime.datetime(2018, 1, 1) into the same data type." )
# Out:
# Are these values the same?
#  True
# Are these values the same?
#  True
# Are these values the same?
#  True
# As you can see, pd.to_datetime converts '1/1/2018', np.datetime64('2018-01-01'), datetime.datetime(2018, 1, 1) into the same data type.

# %%
print(dti[0])
print(dti[0:2])
# Out:
# 2018-01-01 00:00:00
# DatetimeIndex(['2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)

# %%
dates = pd.date_range('1/1/2000', periods=8)

# %% [markdown]
# ## Iniciar una Serie Temporal con Frecuencia de 1 hr.
#
#
# - __Inicio__: 2018-01-01 00:00:00 <br>
# - __Periodo__: 1 hr<br>
# - __Final__: 2018-01-01 02:00:00<br>
# - __Longitud__: 2 hrs<br>
#
# "Una serie temporal también se puede leer como, inicio, cada cuánto tiempo estaremos contando, el final de la serie y la longitud de tiempo que abarca."
#
# Más técnico "Una ventana temporal regular de tres observaciones con frecuencia horaria." [1]
#
# El tiempo transcurrido desde el inicio es de 2 hrs (0-2 hrs) sin embargo los datos registrados son tres. Es decir, en una serie temporal la únidad de información se puede considerar como mínimo tres datos.
#
# Un solo registro se considera un dato flotante, dos registros es una observación asemántica, debido a que si bien, un método de extrapolación funciona con dos datos,

# %%
dti = pd.date_range("2018-01-01", periods=3, freq="h")
dti
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
print("The object is the following: ", dti, "\n")
print("The type is the following: ", type(dti), "\n")
print("The structure is the following: ", str(dti), "\n")
print("The length is the following: ", len(dti), "\n")
print('Methods in dti: ', len(dir(dti)), "\n")
print(dir(dti)[0:5])
print(15*"__", "\nEach element has the following number of methods:\n")
print("The object element is the following: ", dti[0], "\n")
print("The type of the element is: ",type(dti[0]), "\n")
print("The type is the following: ", str(dti[0]), "\n")
print('Metods in dti: ', len(dir(dti[0])))
print(dir(dti[0])[0:5])
# Out:
# The object is the following:  DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)
#
# The type is the following:  <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#
# The structure is the following:  DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)
#
# The length is the following:  3
#
# Methods in dti:  385
#
# ['T', '__abs__', '__abstractmethods__', '__add__', '__and__']
# ______________________________
# Each element has the following number of methods:
#
# The object element is the following:  2018-01-01 00:00:00
#
# The type of the element is:  <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#
# The type is the following:  2018-01-01 00:00:00
#
# Metods in dti:  118
# ['__add__', '__array_priority__', '__class__', '__delattr__', '__dict__']

# %%
for i in dti:
    print(i)
# Out:
# 2018-01-01 00:00:00
# 2018-01-01 01:00:00
# 2018-01-01 02:00:00

# %%
dates = pd.date_range('1/1/2000', periods=8, freq="h")
dates
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:00:00',
#                '2000-01-01 02:00:00', '2000-01-01 03:00:00',
#                '2000-01-01 04:00:00', '2000-01-01 05:00:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %% [markdown]
# ## Iniciar una Serie Temporal con Frecuencia de 1 hr.
#
# En el mundo financiero, es importante manejar datos que permitan identificar el horario y la geolocalización del recurso financiero. Esto con la finalidad de obedecer y cohercionar nuestros modelos con las operaciones de los  participantes del mercado (cadenas de suministro y participantes financieros.)

# %%
dti = pd.date_range("2018-01-01", periods=3, freq="h")
dti = dti.tz_localize("UTC")
dti
# Out:
# DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='h')

# %%
print(dti)
print(type(dti))
print(str(dti))
print(len(dti))
print('Metods in dti: ', len(dir(dti)))
print(dir(dti)[0:5])
print()
# Out:
# DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='h')
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='h')
# 3
# Metods in dti:  385
# ['T', '__abs__', '__abstractmethods__', '__add__', '__and__']

# %%
for i in dti:
    print(i)
# Out:
# 2018-01-01 00:00:00+00:00
# 2018-01-01 01:00:00+00:00
# 2018-01-01 02:00:00+00:00

# %%
dti.tz_convert("US/Pacific")
# Out:
# DatetimeIndex(['2017-12-31 16:00:00-08:00', '2017-12-31 17:00:00-08:00',
#                '2017-12-31 18:00:00-08:00'],
#               dtype='datetime64[ns, US/Pacific]', freq='h')

# %%
for i in dti.tz_convert("US/Pacific"):
    print(i)
# Out:
# 2017-12-31 16:00:00-08:00
# 2017-12-31 17:00:00-08:00
# 2017-12-31 18:00:00-08:00

# %%
for i in dti.tz_convert("CET"):
    print(i)
# Out:
# 2018-01-01 01:00:00+01:00
# 2018-01-01 02:00:00+01:00
# 2018-01-01 03:00:00+01:00

# %%
for i in dti.tz_convert("Europe/Warsaw"):
    print(i)
# Out:
# 2018-01-01 01:00:00+01:00
# 2018-01-01 02:00:00+01:00
# 2018-01-01 03:00:00+01:00

# %%
for i in dti.tz_convert("Asia/Shanghai"):
    print(i)
# Out:
# 2018-01-01 08:00:00+08:00
# 2018-01-01 09:00:00+08:00
# 2018-01-01 10:00:00+08:00

# %%
for i in dti.tz_convert("Europe/Berlin"):
    print(i)
# Out:
# 2018-01-01 01:00:00+01:00
# 2018-01-01 02:00:00+01:00
# 2018-01-01 03:00:00+01:00

# %%
idx = pd.date_range("2018-01-01", periods=5, freq="h")

ts = pd.Series(range(len(idx)), index=idx)

ts
# Out:
# 2018-01-01 00:00:00    0
# 2018-01-01 01:00:00    1
# 2018-01-01 02:00:00    2
# 2018-01-01 03:00:00    3
# 2018-01-01 04:00:00    4
# Freq: h, dtype: int64

# %%
ts["2018-01-01 03:00:00"]
# Out:
# np.int64(3)

# %%
ts["2018-01-01 01:00:00":"2018-01-01 03:00:00"]
# Out:
# 2018-01-01 01:00:00    1
# 2018-01-01 02:00:00    2
# 2018-01-01 03:00:00    3
# Freq: h, dtype: int64

# %% [markdown]
# ## Referencias
#
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tz_convert.html
# 2. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tz_localize.html#pandas.DataFrame.tz_localize
# 3. https://pandas.pydata.org/docs/user_guide/timeseries.html
# 4. https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html
# 5. https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html
